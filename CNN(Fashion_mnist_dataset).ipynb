# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhartha-sai-17/Deep-Learning/blob/main/CNN(Fashion_mnist_dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.datasets import fashion_mnist
from keras import Sequential
from keras.layers import Conv2D,MaxPooling2D,Flatten,Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train,y_train),(x_test,y_test) = fashion_mnist.load_data()

#Display dataset plans
print(f"X_train shape: {x_train.shape}")
print(f"Y_train shape: {y_train.shape}")
print(f"X_test shape: {x_test.shape}")
print(f"Y_test shape: {y_test.shape}")
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# X_train shape: (60000, 28, 28)
# Y_train shape: (60000,)
# X_test shape: (10000, 28, 28)
# Y_test shape: (10000,)

# %%
# Basic Data Visualization
img = x_train[1,:,:]
label = y_train[1]
plt.imshow(img, cmap='gray')
plt.title(f'Label: {label}')
plt.show()

# %%
# Basic Data Visualization
img = x_train[2,:,:]
label = y_train[1]
plt.imshow(img, cmap='gray')
plt.title(f'Label: {label}')
plt.show()

# %%
# Basic Data Visualization
img = x_train[3,:,:]
label = y_train[1]
plt.imshow(img, cmap='gray')
plt.title(f'Label: {label}')
plt.show()

# %%
# Basic Data Visualization
img = x_train[4,:,:]
label = y_train[1]
plt.imshow(img, cmap='gray')
plt.title(f'Label: {label}')
plt.show()

# %%
# Basic Data Visualization
img = x_train[5,:,:]
label = y_train[1]
plt.imshow(img, cmap='gray')
plt.title(f'Label: {label}')
plt.show()

# %%
# Basic Data Visualization
img = x_train[6,:,:]
label = y_train[1]
plt.imshow(img, cmap='gray')
plt.title(f'Label: {label}')
plt.show()

# %%
# Basic Data Visualization
img = x_train[7,:,:]
label = y_train[1]
plt.imshow(img, cmap='gray')
plt.title(f'Label: {label}')
plt.show()

# %%
# Basic Data Visualization
img = x_train[8,:,:]
label = y_train[1]
plt.imshow(img, cmap='gray')
plt.title(f'Label: {label}')
plt.show()

# %%
x_train = x_train.reshape(-1,28,28,1).astype('float32')/255
x_test = x_test.reshape(-1,28,28,1).astype('float32')/255
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
import numpy as np
import matplotlib.pyplot as plt

unique, counts = np.unique(y_train, return_counts=True)

class_counts = dict(zip(unique, counts))

print(class_counts)

plt.bar(unique, counts)
plt.xlabel("Class Label")
plt.ylabel("Number of Images")
plt.title("Fashion MNIST Class Distribution")

plt.show()
# Out:
# {np.float64(0.0): np.int64(540000), np.float64(1.0): np.int64(60000)}

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential([
    Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=(28,28,1)),
    # Detects low-level features like edges and textures

    MaxPooling2D(pool_size=(2,2)),
    # Reduces spatial dimensions while keeping important features

    Conv2D(64, kernel_size=(3,3), activation='relu'),
    # Detects more complex features from previous feature maps

    MaxPooling2D(pool_size=(2,2)),
    # Further reduces spatial size

    Flatten(),
    # Converts 2D feature maps into a 1D vector

    Dense(128, activation='relu'),
    # Fully connected layer for learning complex relationships

    Dense(10, activation='softmax')
    # Output layer for classification into 10 classes
])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=10,batch_size=128,validation_split=0.2)

# Model sees dataset 5 times --> epochs
# Processes 128 images per step --> Batch_size
# Uses 20% of the training data for the validation --> validation split
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7050 - loss: 0.8332 - val_accuracy: 0.8570 - val_loss: 0.4004
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8612 - loss: 0.3848 - val_accuracy: 0.8793 - val_loss: 0.3408
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8811 - loss: 0.3236 - val_accuracy: 0.8846 - val_loss: 0.3234
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8932 - loss: 0.2936 - val_accuracy: 0.8821 - val_loss: 0.3218
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9008 - loss: 0.2705 - val_accuracy: 0.8957 - val_loss: 0.2888
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9083 - loss: 0.2515 - val_accuracy: 0.8979 - val_loss: 0.2826
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9181 - loss: 0.2269 - val_accuracy: 0.8994 - val_loss: 0.2780
# Epoch 8/10
# ...

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9982 - loss: 0.0052 - val_accuracy: 0.9120 - val_loss: 0.8382
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 4.4689e-04 - val_accuracy: 0.9123 - val_loss: 0.8362
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 2.7689e-04 - val_accuracy: 0.9132 - val_loss: 0.8450
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 1.8299e-04 - val_accuracy: 0.9137 - val_loss: 0.8534
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 1.5151e-04 - val_accuracy: 0.9145 - val_loss: 0.8633
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 1.1707e-04 - val_accuracy: 0.9143 - val_loss: 0.8727
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 1.0000 - loss: 1.0233e-04 - val_accuracy: 0.9143 - val_loss: 0.8785
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title("Training vs Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")

plt.legend(["Train Accuracy", "Validation Accuracy"])

plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title("Training vs Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")

plt.legend(["Train Loss", "Validation Loss"])

plt.show()

# %%
test_loss,test_accuracy = model.evaluate(x_test,y_test)
print(f"Test accuracy: {test_accuracy}")
print(f"Test loss: {test_loss}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9120 - loss: 0.9898
# Test accuracy: 0.9117000102996826
# Test loss: 0.968336820602417

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test.argmax(axis=1),model.predict(x_test).argmax(axis=1))
print(cm)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# [[849   0  16  16   4   1 106   1   7   0]
#  [  0 986   1   6   2   0   3   0   2   0]
#  [ 16   1 873   7  46   0  54   1   2   0]
#  [ 20   2   9 912  24   0  29   0   3   1]
#  [  1   0  55  21 876   0  42   0   5   0]
#  [  0   0   0   0   0 980   0  15   0   5]
#  [ 99   1  71  26  52   0 740   0  11   0]
#  [  0   0   0   0   0  15   0 965   0  20]
#  [  2   0   4   2   3   1   4   3 979   2]
#  [  1   0   0   0   0  10   0  32   0 957]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

sns.heatmap(cm,
            annot=True,
            fmt='d',
            cmap='Blues')

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")

plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model1 = Sequential([
    Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)),
    MaxPooling2D((2,2)),

    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D((2,2)),

    Flatten(),
    Dense(128,activation='relu'),
    Dense(10,activation='softmax')
])
model1.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history1 = model1.fit(
    x_train, y_train,
    epochs=10,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7628 - loss: 0.6591 - val_accuracy: 0.8733 - val_loss: 0.3542
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8843 - loss: 0.3195 - val_accuracy: 0.8932 - val_loss: 0.2913
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9002 - loss: 0.2654 - val_accuracy: 0.9026 - val_loss: 0.2715
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9151 - loss: 0.2265 - val_accuracy: 0.9015 - val_loss: 0.2696
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9254 - loss: 0.1986 - val_accuracy: 0.9045 - val_loss: 0.2684
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9327 - loss: 0.1781 - val_accuracy: 0.9067 - val_loss: 0.2645
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9431 - loss: 0.1525 - val_accuracy: 0.9117 - val_loss: 0.2569
# Epoch 8/10
# ...

# %%
from tensorflow.keras.layers import Dropout

model2 = Sequential([

    Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)),
    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D((2,2)),

    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D((2,2)),

    Flatten(),

    Dense(128,activation='relu'),
    Dropout(0.5),

    Dense(10,activation='softmax')
])

model2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history2 = model2.fit(
    x_train, y_train,
    epochs=10,
    validation_split=0.2
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.7073 - loss: 0.8082 - val_accuracy: 0.8737 - val_loss: 0.3395
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8583 - loss: 0.3918 - val_accuracy: 0.8944 - val_loss: 0.2899
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8832 - loss: 0.3249 - val_accuracy: 0.8938 - val_loss: 0.2866
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8972 - loss: 0.2855 - val_accuracy: 0.9045 - val_loss: 0.2588
# Epoch 5/10
# ...

# %%
test_loss1, test_acc1 = model1.evaluate(x_test,y_test)
test_loss2, test_acc2 = model2.evaluate(x_test,y_test)

print("Model 1 Accuracy:",test_acc1)
print("Model 2 Accuracy:",test_acc2)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9064 - loss: 0.3237
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9109 - loss: 0.2901
# Model 1 Accuracy: 0.9064000248908997
# Model 2 Accuracy: 0.9140999913215637

# %%
import matplotlib.pyplot as plt

plt.plot(history1.history['val_accuracy'],label='Model 1')
plt.plot(history2.history['val_accuracy'],label='Model 2')

plt.title("Model Accuracy Comparison")
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")

plt.legend()

plt.show()

# %%
import numpy as np

y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

y_test_labels = np.argmax(y_test, axis=1)

misclassified = np.where(y_pred_classes != y_test_labels)[0]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt

y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

y_test_labels = np.argmax(y_test, axis=1)

misclassified = np.where(y_pred_classes != y_test_labels)[0]

class_names = [
'T-shirt','Trouser','Pullover','Dress','Coat',
'Sandal','Shirt','Sneaker','Bag','Ankle Boot'
]

plt.figure(figsize=(10,5))

for i in range(5):

    index = misclassified[i]

    plt.subplot(1,5,i+1)
    plt.imshow(x_test[index], cmap='gray')

    plt.title(
        f"Actual: {class_names[y_test_labels[index]]}\nPred: {class_names[y_pred_classes[index]]}"
    )

    plt.axis('off')

plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
from tensorflow.keras.models import Model

layer_outputs = [layer.output for layer in model.layers if "conv" in layer.name]

feature_map_model = Model(inputs=model.inputs, outputs=layer_outputs)
import numpy as np

image = x_test[0]
image = np.expand_dims(image, axis=0)
feature_maps = feature_map_model.predict(image)
import matplotlib.pyplot as plt

layer = feature_maps[0]   # first conv layer output

plt.figure(figsize=(10,10))

for i in range(16):   # show first 16 feature maps

    plt.subplot(4,4,i+1)
    plt.imshow(layer[0,:,:,i], cmap='gray')
    plt.axis('off')

plt.suptitle("Feature Maps from First Convolution Layer")

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
# Basic Data Visualization
img = x_train[43,:,:]
label = y_train[32]
plt.imshow(img, cmap='gray')
plt.title(f'Label: {label}')
plt.show()
