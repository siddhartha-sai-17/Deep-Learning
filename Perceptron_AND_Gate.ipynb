# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhartha-sai-17/Deep-Learning/blob/main/Perceptron_AND_Gate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Perceptron AND Gate**

# %%
import numpy as np

# %%
X = np.array([[0,0],
              [0,1],
              [1,0],
              [1,1]
              ])
y = np.array([0,0,0,1])
X,y
# Out:
# (array([[0, 0],
#         [0, 1],
#         [1, 0],
#         [1, 1]]),
#  array([0, 0, 0, 1]))

# %%
w = [0,0]
b = 0
epochs = 10
learning_rate = 0.1
print("Initial Weight:",w)
print("Initial Bias:",b)
# Out:
# Initial Weight: [0, 0]
# Initial Bias: 0

# %%
def step_function(z):
  return 1 if z>=0 else 0

# %%
for i in range(len(X)):
        # 1. Weighted sum (dot product)
        z = np.dot(w, X[i]) + b

        # 2. Activation
        y_pred = step_function(z)

        # 3. Error
        error = y[i] - y_pred

        # 4. Update weights
        w = w + learning_rate * error * X[i]

        # 5. Update bias
        b = b + learning_rate * error

        print(f"Input: {X[i]}, Predicted: {y_pred}, Actual: {y[i]}, w: {w}, b: {b}")

print("\nFinal Weights:", w)
print("Final Bias:", b)
# Out:
# Input: [0 0], Predicted: 0, Actual: 0, w: [0.2 0.1], b: -0.20000000000000004
# Input: [0 1], Predicted: 0, Actual: 0, w: [0.2 0.1], b: -0.20000000000000004
# Input: [1 0], Predicted: 0, Actual: 0, w: [0.2 0.1], b: -0.20000000000000004
# Input: [1 1], Predicted: 1, Actual: 1, w: [0.2 0.1], b: -0.20000000000000004
#
# Final Weights: [0.2 0.1]
# Final Bias: -0.20000000000000004

# %%
# -----------------------------
# 4. Plot Decision Boundary
# -----------------------------
plt.figure()

# Plot class 0 points
plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1])

# Plot class 1 point
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1])

# Decision boundary:
# w1*x1 + w2*x2 + b = 0
# x2 = -(w1*x1 + b)/w2
x1_values = np.linspace(-0.5, 1.5, 100)
x2_values = -(w[0] * x1_values + b) / w[1]

plt.plot(x1_values, x2_values)

plt.xlabel("x1")
plt.ylabel("x2")
plt.title("Perceptron Decision Boundary (AND Gate)")
plt.xlim(-0.5, 1.5)
plt.ylim(-0.5, 1.5)

plt.show()
